# %% [markdown]
# <a href="https://colab.research.google.com/github/Moncho2703/Practicas-de-Python/blob/master/Exercisises_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Create an array of 9 evenly spaced numbers going from 0 to 29 (inclusive) and give it the variable name r
#2. Find the square of each element of the array (as simply as possible) and give it the variable name r2
#3. Find twice the value of each element of the array in two different ways: i) using addition and ii) multiplication. Print out the array r3

a = np.linspace(0, 29, 9)
import numpy as np
r =np.array(a)
print(r)

r2= np.sqrt (r)
print(r2)

r3= r + r
print(r3)

r3 = r * r
print(r3)
# Out:
# [ 0.     3.625  7.25  10.875 14.5   18.125 21.75  25.375 29.   ]
# [0.         1.90394328 2.6925824  3.29772649 3.80788655 4.25734659
#  4.66368953 5.03736042 5.38516481]
# [ 0.    7.25 14.5  21.75 29.   36.25 43.5  50.75 58.  ]
# [  0.        13.140625  52.5625   118.265625 210.25     328.515625
#  473.0625   643.890625 841.      ]

# %%
#Create an array of 100 elements all equal to e, the base of the natural logerithm;
# Create an array in 1 degree increments of all angles in degrees from o to 360 degrees inclusive;
import numpy as np
a = np.arange(0, 100, 1)
e= np.exp(a)
print(e) 

a= np.arange(0, 360, 1)
print(a)
# Out:
# [1.00000000e+00 2.71828183e+00 7.38905610e+00 2.00855369e+01
#  5.45981500e+01 1.48413159e+02 4.03428793e+02 1.09663316e+03
#  2.98095799e+03 8.10308393e+03 2.20264658e+04 5.98741417e+04
#  1.62754791e+05 4.42413392e+05 1.20260428e+06 3.26901737e+06
#  8.88611052e+06 2.41549528e+07 6.56599691e+07 1.78482301e+08
#  4.85165195e+08 1.31881573e+09 3.58491285e+09 9.74480345e+09
#  2.64891221e+10 7.20048993e+10 1.95729609e+11 5.32048241e+11
#  1.44625706e+12 3.93133430e+12 1.06864746e+13 2.90488497e+13
#  7.89629602e+13 2.14643580e+14 5.83461743e+14 1.58601345e+15
#  4.31123155e+15 1.17191424e+16 3.18559318e+16 8.65934004e+16
#  2.35385267e+17 6.39843494e+17 1.73927494e+18 4.72783947e+18
#  1.28516001e+19 3.49342711e+19 9.49611942e+19 2.58131289e+20
#  7.01673591e+20 1.90734657e+21 5.18470553e+21 1.40934908e+22
#  3.83100800e+22 1.04137594e+23 2.83075330e+23 7.69478527e+23
#  2.09165950e+24 5.68572000e+24 1.54553894e+25 4.20121040e+25
# ...
